# %%
import pandas as pd

# %%
import plotly.express as px

# %%
gapminder = px.data.gapminder()

# %%
gapminder.head(20)
# Out:
#         country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314       AFG
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030       AFG
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710       AFG
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138       AFG
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106       AFG
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360       AFG
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439       AFG
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945       AFG
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395       AFG
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351       AFG
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055       AFG
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338       AFG
# ...

# %%
df=pd.read_csv('data\zaisei_detail.csv', index_col=0)
df
# Out:
#                  title         1997         1998         1999         2000  \
# 0                  皇室費      6686157      6643501      6832632      9366209
# 1                  国会費    123019403    131142130    138585747    146463865
# 2                  選挙費      3534438     57491037      3258220     73263020
# 3           司法、警察及び消防費   1319365876   1399227861   1408610493   1453162305
# 4                  外交費    831845677    861739833    888920739    865866900
# 5                一般行政費   1054750965   1049312336   1055053630   1471169953
# 6                  徴税費    750676414    775282398    772413149    783476331
# 7                貨幣製造費            0            0            0            0
# 8              地方財政調整費  15480975000  14304580000  13084335000  15828908673
# 9                 元利補給      4788629      3441917      2442715      1616353
# 10                 その他     18154342     18216295     18234008     18936408
# ...

# %%
df.melt(id_vars=['main_title', 'title'])
# Out:
#               main_title               title variable       value
# 0            １．国 家 機 関 費                 皇室費     1997     6686157
# 1            １．国 家 機 関 費                 国会費     1997   123019403
# 2            １．国 家 機 関 費                 選挙費     1997     3534438
# 3            １．国 家 機 関 費          司法、警察及び消防費     1997  1319365876
# 4            １．国 家 機 関 費                 外交費     1997   831845677
# ...                  ...                 ...      ...         ...
# 1271  10.経済危機対応・地域活性化予備費  10.経済危機対応・地域活性化予備費     2018           0
# 1272   11.東日本大震災復旧・復興予備費   11.東日本大震災復旧・復興予備費     2018           0
# 1273       12.熊本地震復旧等予備費       12.熊本地震復旧等予備費     2018           0
# 1274          12．予　　備　　費          12．予　　備　　費     2018           0
# 1275          13．そ　　の　　他          13．そ　　の　　他     2018   940610781
#
# [1276 rows x 4 columns]
